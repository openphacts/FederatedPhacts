# %% [markdown]
# ## Given a compound retrieve a tissue expression profile
#
# * August 20, 2019
# * Workshop - FederatedPhacts
# * Paul Groth, Egon Willighagen, Alasdair Gray, Nick Juty, Alan Gateau, Chris Evelo
#
#
# * What we're doing:
#    * experiment with using grlc encapsulated sparql queries in combination with normal sparql queries
#    * merging wikidata, chembl, nextprot data
#    * mapping done both externally and internally
#    * fun with using wikidata to do autosuggest search

# %%
from IPython.display import display
from SPARQLWrapper import SPARQLWrapper, JSON
import wikipedia
import wikidata
import requests
import pandas as pd
from ipywidgets import interact, widgets
from IPython.display import display
import itertools

# %% [markdown]
# ### Wikidata search functions

# %%
def wikidata_search(search_str):
    wd_search_param = {"action":"wbsearchentities", "format": "json", "limit":"1","language":"en","search":search_str}
    wd_search_url = "https://www.wikidata.org/w/api.php"
    r = requests.get(wd_search_url, params = wd_search_param)
    return r.json()

# %%
search_results = widgets.Label(value="")

text = widgets.Text(
    value='last',
    placeholder='Search',
    description='String:',
    disabled=False,
    continuous_update=True
)


def callback(update):
    search_str = update["new"]
    displaystring = ""
    r = wikidata_search(search_str)
    if "search" in r:
        for i in r["search"]:
            displaystring = displaystring + i["id"] + " | " + i["match"]["text"]
            if "description" in i:
                displaystring = displaystring + " | " + i["description"]
    search_results.value = displaystring
    

def finalize(input):
    finalresult = search_results.value
    

text.observe(callback, 'value')
text.on_submit(finalize)

# %% [markdown]
# ___Run the next two cells to see the search box and the search results. What you see in the search results will be input to the subsequent cells___

# %%
display(text)
# Out:
# Text(value='last', description='String:', placeholder='Search')

# %%
display(search_results)
# Out:
# Label(value='')

# %%
wd_query_id = search_results.value.split(" | ")[0]

# %%
wd_query_id
# Out:
# 'Q177094'

# %% [markdown]
# ### Map a Wikidata chemical id to CHEBL

# %%
def wikidataid_to_chembl_id(wikidataid):
    wdtochem_params = {"wdID" : wikidataid}
    headers = {"accept" : "application/json"}
    wdtochem_param_url = "http://grlc.io/api/openphacts/FederatedPhacts/wikidata-chemical-id-mapping"
    r = requests.get(wdtochem_param_url, params = wdtochem_params, headers=headers)
    return r.json()

# %%
chemblid = wikidataid_to_chembl_id("http://www.wikidata.org/entity/Q421136")["results"]["bindings"][0]["chemblIRI"]["value"]

# %%
chemblid
# Out:
# 'http://rdf.ebi.ac.uk/resource/chembl/molecule/CHEMBL1336'

# %% [markdown]
# ### Get a set of uniprot protein targets related to the particular chemical through an assay

# %%
targetquery = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX dc: <http://purl.org/dc/elements/1.1/>
PREFIX dcterms: <http://purl.org/dc/terms/>
PREFIX dbpedia2: <http://dbpedia.org/property/>
PREFIX dbpedia: <http://dbpedia.org/>
PREFIX foaf: <http://xmlns.com/foaf/0.1/>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>

PREFIX cco: <http://rdf.ebi.ac.uk/terms/chembl#>
PREFIX chembl_molecule: <http://rdf.ebi.ac.uk/resource/chembl/molecule/>
SELECT ?assay ?target ?uniprot
WHERE {{
    # ?activity a cco:Activity ;
    cco:hasMolecule <{chemical}> ;
    cco:hasAssay ?assay .
    # ?assay cco:hasTarget ?target .
    # ?target cco:hasTargetComponent ?targetcmpt .
    # ?targetcmpt cco:targetCmptXref ?uniprot .
    # ?uniprot a cco:UniprotRef .
}}
""".format(chemical=chemblid)

# %%
sparql_chembl = SPARQLWrapper("https://www.ebi.ac.uk/rdf/services/sparql")
sparql_chembl.setQuery(targetquery)
sparql_chembl.setReturnFormat(JSON)
results = sparql_chembl.query().convert()

target_list = []
for r in results['results']['bindings']:
    target_list.append(r["uniprot"]['value'])

# %%
target_list = set(target_list)

# %%
display(target_list)
# Out:
# {'http://purl.uniprot.org/uniprot/O00141',
#  'http://purl.uniprot.org/uniprot/O00238',
#  'http://purl.uniprot.org/uniprot/O00255',
#  'http://purl.uniprot.org/uniprot/O00311',
#  'http://purl.uniprot.org/uniprot/O00329',
#  'http://purl.uniprot.org/uniprot/O00418',
#  'http://purl.uniprot.org/uniprot/O00444',
#  'http://purl.uniprot.org/uniprot/O00506',
#  'http://purl.uniprot.org/uniprot/O00750',
#  'http://purl.uniprot.org/uniprot/O14578',
#  'http://purl.uniprot.org/uniprot/O14730',
#  'http://purl.uniprot.org/uniprot/O14733',
#  'http://purl.uniprot.org/uniprot/O14757',
#  'http://purl.uniprot.org/uniprot/O14920',
#  'http://purl.uniprot.org/uniprot/O14936',
#  'http://purl.uniprot.org/uniprot/O14965',
#  'http://purl.uniprot.org/uniprot/O14976',
#  'http://purl.uniprot.org/uniprot/O15075',
#  'http://purl.uniprot.org/uniprot/O15111',
#  'http://purl.uniprot.org/uniprot/O15146',
#  'http://purl.uniprot.org/uniprot/O15197',
#  'http://purl.uniprot.org/uniprot/O15264',
#  'http://purl.uniprot.org/uniprot/O15530',
#  'http://purl.uniprot.org/uniprot/O15648',
#  'http://purl.uniprot.org/uniprot/O43172',
#  'http://purl.uniprot.org/uniprot/O43283',
#  'http://purl.uniprot.org/uniprot/O43293',
#  'http://purl.uniprot.org/uniprot/O43318',
#  'http://purl.uniprot.org/uniprot/O43353',
#  'http://purl.uniprot.org/uniprot/O43781',
#  'http://purl.uniprot.org/uniprot/O60285',
#  'http://purl.uniprot.org/uniprot/O60331',
#  'http://purl.uniprot.org/uniprot/O60563',
#  'http://purl.uniprot.org/uniprot/O60674',
#  'http://purl.uniprot.org/uniprot/O75116',
#  'http://purl.uniprot.org/uniprot/O75385',
#  'http://purl.uniprot.org/uniprot/O75460',
#  'http://purl.uniprot.org/uniprot/O75496',
#  'http://purl.uniprot.org/uniprot/O75582',
#  'http://purl.uniprot.org/uniprot/O75676',
#  'http://purl.uniprot.org/uniprot/O75716',
#  'http://purl.uniprot.org/uniprot/O75747',
#  'http://purl.uniprot.org/uniprot/O75909',
#  'http://purl.uniprot.org/uniprot/O75914',
#  'http://purl.uniprot.org/uniprot/O76039',
#  'http://purl.uniprot.org/uniprot/O94768',
#  'http://purl.uniprot.org/uniprot/O94782',
#  'http://purl.uniprot.org/uniprot/O94804',
#  'http://purl.uniprot.org/uniprot/O94806',
#  'http://purl.uniprot.org/uniprot/O94921',
#  'http://purl.uniprot.org/uniprot/O95382',
#  'http://purl.uniprot.org/uniprot/O95747',
#  'http://purl.uniprot.org/uniprot/O95819',
#  'http://purl.uniprot.org/uniprot/O95835',
#  'http://purl.uniprot.org/uniprot/O96013',
#  'http://purl.uniprot.org/uniprot/O96017',
#  'http://purl.uniprot.org/uniprot/P00519',
#  'http://purl.uniprot.org/uniprot/P00520',
#  'http://purl.uniprot.org/uniprot/P00523',
#  'http://purl.uniprot.org/uniprot/P00533',
#  'http://purl.uniprot.org/uniprot/P04049',
#  'http://purl.uniprot.org/uniprot/P04626',
#  'http://purl.uniprot.org/uniprot/P04629',
#  'http://purl.uniprot.org/uniprot/P05129',
#  'http://purl.uniprot.org/uniprot/P05622',
#  'http://purl.uniprot.org/uniprot/P06213',
#  'http://purl.uniprot.org/uniprot/P06239',
#  'http://purl.uniprot.org/uniprot/P06240',
#  'http://purl.uniprot.org/uniprot/P06241',
#  'http://purl.uniprot.org/uniprot/P06493',
#  'http://purl.uniprot.org/uniprot/P07332',
#  'http://purl.uniprot.org/uniprot/P07333',
#  'http://purl.uniprot.org/uniprot/P07947',
#  'http://purl.uniprot.org/uniprot/P07948',
#  'http://purl.uniprot.org/uniprot/P07949',
#  'http://purl.uniprot.org/uniprot/P08069',
#  'http://purl.uniprot.org/uniprot/P08581',
#  'http://purl.uniprot.org/uniprot/P08631',
#  'http://purl.uniprot.org/uniprot/P08908',
#  'http://purl.uniprot.org/uniprot/P08922',
#  'http://purl.uniprot.org/uniprot/P09619',
#  'http://purl.uniprot.org/uniprot/P09769',
#  'http://purl.uniprot.org/uniprot/P0C1S8',
#  'http://purl.uniprot.org/uniprot/P0C264',
#  'http://purl.uniprot.org/uniprot/P10721',
#  'http://purl.uniprot.org/uniprot/P11274',
#  'http://purl.uniprot.org/uniprot/P11309',
#  'http://purl.uniprot.org/uniprot/P11362',
#  'http://purl.uniprot.org/uniprot/P11799',
#  'http://purl.uniprot.org/uniprot/P11802',
#  'http://purl.uniprot.org/uniprot/P12931',
#  'http://purl.uniprot.org/uniprot/P14616',
#  'http://purl.uniprot.org/uniprot/P15056',
#  'http://purl.uniprot.org/uniprot/P15735',
#  'http://purl.uniprot.org/uniprot/P16234',
#  'http://purl.uniprot.org/uniprot/P16591',
#  'http://purl.uniprot.org/uniprot/P17252',
#  'http://purl.uniprot.org/uniprot/P17612',
#  'http://purl.uniprot.org/uniprot/P17948',
#  'http://purl.uniprot.org/uniprot/P19525',
#  'http://purl.uniprot.org/uniprot/P19784',
#  'http://purl.uniprot.org/uniprot/P20248',
#  'http://purl.uniprot.org/uniprot/P20794',
#  'http://purl.uniprot.org/uniprot/P21127',
#  'http://purl.uniprot.org/uniprot/P21709',
#  'http://purl.uniprot.org/uniprot/P21802',
#  'http://purl.uniprot.org/uniprot/P21860',
#  'http://purl.uniprot.org/uniprot/P22455',
#  'http://purl.uniprot.org/uniprot/P22607',
#  'http://purl.uniprot.org/uniprot/P22694',
#  'http://purl.uniprot.org/uniprot/P23443',
#  'http://purl.uniprot.org/uniprot/P23458',
#  'http://purl.uniprot.org/uniprot/P24385',
#  'http://purl.uniprot.org/uniprot/P24723',
#  'http://purl.uniprot.org/uniprot/P24941',
#  'http://purl.uniprot.org/uniprot/P25094',
#  'http://purl.uniprot.org/uniprot/P27037',
#  'http://purl.uniprot.org/uniprot/P27361',
#  'http://purl.uniprot.org/uniprot/P27448',
#  'http://purl.uniprot.org/uniprot/P28222',
#  'http://purl.uniprot.org/uniprot/P28223',
#  'http://purl.uniprot.org/uniprot/P28335',
#  'http://purl.uniprot.org/uniprot/P28482',
#  'http://purl.uniprot.org/uniprot/P28566',
#  'http://purl.uniprot.org/uniprot/P29317',
#  'http://purl.uniprot.org/uniprot/P29320',
#  'http://purl.uniprot.org/uniprot/P29322',
#  'http://purl.uniprot.org/uniprot/P29323',
#  'http://purl.uniprot.org/uniprot/P29350',
#  'http://purl.uniprot.org/uniprot/P29376',
#  'http://purl.uniprot.org/uniprot/P29597',
#  'http://purl.uniprot.org/uniprot/P30291',
#  'http://purl.uniprot.org/uniprot/P30530',
#  'http://purl.uniprot.org/uniprot/P30939',
#  'http://purl.uniprot.org/uniprot/P31152',
#  'http://purl.uniprot.org/uniprot/P31749',
#  'http://purl.uniprot.org/uniprot/P31751',
#  'http://purl.uniprot.org/uniprot/P32298',
#  'http://purl.uniprot.org/uniprot/P33981',
#  'http://purl.uniprot.org/uniprot/P34913',
#  'http://purl.uniprot.org/uniprot/P34947',
#  'http://purl.uniprot.org/uniprot/P34969',
#  'http://purl.uniprot.org/uniprot/P35590',
#  'http://purl.uniprot.org/uniprot/P35916',
#  'http://purl.uniprot.org/uniprot/P35968',
#  'http://purl.uniprot.org/uniprot/P36507',
#  'http://purl.uniprot.org/uniprot/P36888',
#  'http://purl.uniprot.org/uniprot/P36894',
#  'http://purl.uniprot.org/uniprot/P36896',
#  'http://purl.uniprot.org/uniprot/P36897',
#  'http://purl.uniprot.org/uniprot/P37023',
#  'http://purl.uniprot.org/uniprot/P37173',
#  'http://purl.uniprot.org/uniprot/P37840',
#  'http://purl.uniprot.org/uniprot/P41240',
#  'http://purl.uniprot.org/uniprot/P41595',
#  'http://purl.uniprot.org/uniprot/P41743',
#  'http://purl.uniprot.org/uniprot/P42336',
#  'http://purl.uniprot.org/uniprot/P42338',
#  'http://purl.uniprot.org/uniprot/P42345',
#  'http://purl.uniprot.org/uniprot/P42679',
#  'http://purl.uniprot.org/uniprot/P42680',
#  'http://purl.uniprot.org/uniprot/P42681',
#  'http://purl.uniprot.org/uniprot/P42684',
#  'http://purl.uniprot.org/uniprot/P42685',
#  'http://purl.uniprot.org/uniprot/P43403',
#  'http://purl.uniprot.org/uniprot/P43405',
#  'http://purl.uniprot.org/uniprot/P45983',
#  'http://purl.uniprot.org/uniprot/P45984',
#  'http://purl.uniprot.org/uniprot/P45985',
#  'http://purl.uniprot.org/uniprot/P46098',
#  'http://purl.uniprot.org/uniprot/P46734',
#  'http://purl.uniprot.org/uniprot/P47898',
#  'http://purl.uniprot.org/uniprot/P48729',
#  'http://purl.uniprot.org/uniprot/P48730',
#  'http://purl.uniprot.org/uniprot/P48736',
#  'http://purl.uniprot.org/uniprot/P49137',
#  'http://purl.uniprot.org/uniprot/P49336',
#  'http://purl.uniprot.org/uniprot/P49674',
#  'http://purl.uniprot.org/uniprot/P49759',
#  'http://purl.uniprot.org/uniprot/P49760',
#  'http://purl.uniprot.org/uniprot/P49761',
#  'http://purl.uniprot.org/uniprot/P49840',
#  'http://purl.uniprot.org/uniprot/P49841',
#  'http://purl.uniprot.org/uniprot/P50406',
#  'http://purl.uniprot.org/uniprot/P50613',
#  'http://purl.uniprot.org/uniprot/P50750',
#  'http://purl.uniprot.org/uniprot/P51450',
#  'http://purl.uniprot.org/uniprot/P51451',
#  'http://purl.uniprot.org/uniprot/P51617',
#  'http://purl.uniprot.org/uniprot/P51812',
#  'http://purl.uniprot.org/uniprot/P51813',
#  'http://purl.uniprot.org/uniprot/P51817',
#  'http://purl.uniprot.org/uniprot/P51955',
#  'http://purl.uniprot.org/uniprot/P51956',
#  'http://purl.uniprot.org/uniprot/P51957',
#  'http://purl.uniprot.org/uniprot/P52333',
#  'http://purl.uniprot.org/uniprot/P52564',
#  'http://purl.uniprot.org/uniprot/P53350',
#  'http://purl.uniprot.org/uniprot/P53355',
#  'http://purl.uniprot.org/uniprot/P53667',
#  'http://purl.uniprot.org/uniprot/P53671',
#  'http://purl.uniprot.org/uniprot/P53778',
#  'http://purl.uniprot.org/uniprot/P53779',
#  'http://purl.uniprot.org/uniprot/P54646',
#  'http://purl.uniprot.org/uniprot/P54753',
#  'http://purl.uniprot.org/uniprot/P54756',
#  'http://purl.uniprot.org/uniprot/P54760',
#  'http://purl.uniprot.org/uniprot/P54762',
#  'http://purl.uniprot.org/uniprot/P54764',
#  'http://purl.uniprot.org/uniprot/P57058',
#  'http://purl.uniprot.org/uniprot/P57059',
#  'http://purl.uniprot.org/uniprot/P57078',
#  'http://purl.uniprot.org/uniprot/P61075',
#  'http://purl.uniprot.org/uniprot/P62344',
#  'http://purl.uniprot.org/uniprot/P67870',
#  'http://purl.uniprot.org/uniprot/P68370',
#  'http://purl.uniprot.org/uniprot/P68400',
#  'http://purl.uniprot.org/uniprot/P78356',
#  'http://purl.uniprot.org/uniprot/P78362',
#  'http://purl.uniprot.org/uniprot/P78368',
#  'http://purl.uniprot.org/uniprot/P78396',
#  'http://purl.uniprot.org/uniprot/P78527',
#  'http://purl.uniprot.org/uniprot/P80192',
#  'http://purl.uniprot.org/uniprot/P80370',
#  'http://purl.uniprot.org/uniprot/P84022',
#  'http://purl.uniprot.org/uniprot/P9WI81',
#  'http://purl.uniprot.org/uniprot/Q00526',
#  'http://purl.uniprot.org/uniprot/Q00532',
#  'http://purl.uniprot.org/uniprot/Q00534',
#  'http://purl.uniprot.org/uniprot/Q00535',
#  'http://purl.uniprot.org/uniprot/Q00536',
#  'http://purl.uniprot.org/uniprot/Q00537',
#  'http://purl.uniprot.org/uniprot/Q02156',
#  'http://purl.uniprot.org/uniprot/Q02750',
#  'http://purl.uniprot.org/uniprot/Q02763',
#  'http://purl.uniprot.org/uniprot/Q02779',
#  'http://purl.uniprot.org/uniprot/Q03164',
#  'http://purl.uniprot.org/uniprot/Q04759',
#  'http://purl.uniprot.org/uniprot/Q04771',
#  'http://purl.uniprot.org/uniprot/Q04912',
#  'http://purl.uniprot.org/uniprot/Q05397',
#  'http://purl.uniprot.org/uniprot/Q05513',
#  'http://purl.uniprot.org/uniprot/Q05655',
#  'http://purl.uniprot.org/uniprot/Q06187',
#  'http://purl.uniprot.org/uniprot/Q06418',
#  'http://purl.uniprot.org/uniprot/Q07002',
#  'http://purl.uniprot.org/uniprot/Q07912',
#  'http://purl.uniprot.org/uniprot/Q08345',
#  'http://purl.uniprot.org/uniprot/Q08881',
#  'http://purl.uniprot.org/uniprot/Q09013',
#  'http://purl.uniprot.org/uniprot/Q12851',
#  'http://purl.uniprot.org/uniprot/Q12852',
#  'http://purl.uniprot.org/uniprot/Q12866',
#  'http://purl.uniprot.org/uniprot/Q13043',
#  'http://purl.uniprot.org/uniprot/Q13131',
#  'http://purl.uniprot.org/uniprot/Q13153',
#  'http://purl.uniprot.org/uniprot/Q13163',
#  'http://purl.uniprot.org/uniprot/Q13164',
#  'http://purl.uniprot.org/uniprot/Q13177',
#  'http://purl.uniprot.org/uniprot/Q13188',
#  'http://purl.uniprot.org/uniprot/Q13233',
#  'http://purl.uniprot.org/uniprot/Q13237',
#  'http://purl.uniprot.org/uniprot/Q13464',
#  'http://purl.uniprot.org/uniprot/Q13470',
#  'http://purl.uniprot.org/uniprot/Q13523',
#  'http://purl.uniprot.org/uniprot/Q13546',
#  'http://purl.uniprot.org/uniprot/Q13554',
#  'http://purl.uniprot.org/uniprot/Q13555',
#  'http://purl.uniprot.org/uniprot/Q13557',
#  'http://purl.uniprot.org/uniprot/Q13627',
#  'http://purl.uniprot.org/uniprot/Q13705',
#  'http://purl.uniprot.org/uniprot/Q13873',
#  'http://purl.uniprot.org/uniprot/Q13882',
#  'http://purl.uniprot.org/uniprot/Q13976',
#  'http://purl.uniprot.org/uniprot/Q14004',
#  'http://purl.uniprot.org/uniprot/Q14012',
#  'http://purl.uniprot.org/uniprot/Q14164',
#  'http://purl.uniprot.org/uniprot/Q14289',
#  'http://purl.uniprot.org/uniprot/Q14680',
#  'http://purl.uniprot.org/uniprot/Q15139',
#  'http://purl.uniprot.org/uniprot/Q15208',
#  'http://purl.uniprot.org/uniprot/Q15303',
#  'http://purl.uniprot.org/uniprot/Q15349',
#  'http://purl.uniprot.org/uniprot/Q15375',
#  'http://purl.uniprot.org/uniprot/Q15418',
#  'http://purl.uniprot.org/uniprot/Q15569',
#  'http://purl.uniprot.org/uniprot/Q15746',
#  'http://purl.uniprot.org/uniprot/Q15759',
#  'http://purl.uniprot.org/uniprot/Q15831',
#  'http://purl.uniprot.org/uniprot/Q15835',
#  'http://purl.uniprot.org/uniprot/Q16288',
#  'http://purl.uniprot.org/uniprot/Q16512',
#  'http://purl.uniprot.org/uniprot/Q16513',
#  'http://purl.uniprot.org/uniprot/Q16539',
#  'http://purl.uniprot.org/uniprot/Q16566',
#  'http://purl.uniprot.org/uniprot/Q16584',
#  'http://purl.uniprot.org/uniprot/Q16620',
#  'http://purl.uniprot.org/uniprot/Q16644',
#  'http://purl.uniprot.org/uniprot/Q16659',
#  'http://purl.uniprot.org/uniprot/Q16816',
#  'http://purl.uniprot.org/uniprot/Q16832',
#  'http://purl.uniprot.org/uniprot/Q2M2I8',
#  'http://purl.uniprot.org/uniprot/Q32MK0',
#  'http://purl.uniprot.org/uniprot/Q3U3Q1',
#  'http://purl.uniprot.org/uniprot/Q52WX2',
#  'http://purl.uniprot.org/uniprot/Q56UN5',
#  'http://purl.uniprot.org/uniprot/Q59H18',
#  'http://purl.uniprot.org/uniprot/Q5GIT4',
#  'http://purl.uniprot.org/uniprot/Q5S007',
#  'http://purl.uniprot.org/uniprot/Q5VT25',
#  'http://purl.uniprot.org/uniprot/Q6DT37',
#  'http://purl.uniprot.org/uniprot/Q6P3R8',
#  'http://purl.uniprot.org/uniprot/Q6PHR2',
#  'http://purl.uniprot.org/uniprot/Q6XUX3',
#  'http://purl.uniprot.org/uniprot/Q6ZN16',
#  'http://purl.uniprot.org/uniprot/Q7KZI7',
#  'http://purl.uniprot.org/uniprot/Q7L7X3',
#  'http://purl.uniprot.org/uniprot/Q86UE8',
#  'http://purl.uniprot.org/uniprot/Q86UX6',
#  'http://purl.uniprot.org/uniprot/Q86V86',
#  'http://purl.uniprot.org/uniprot/Q86Y07',
#  'http://purl.uniprot.org/uniprot/Q86YV6',
#  'http://purl.uniprot.org/uniprot/Q86Z02',
#  'http://purl.uniprot.org/uniprot/Q8IU85',
#  'http://purl.uniprot.org/uniprot/Q8IVH8',
#  'http://purl.uniprot.org/uniprot/Q8IVW4',
#  'http://purl.uniprot.org/uniprot/Q8IW41',
#  'http://purl.uniprot.org/uniprot/Q8IWQ3',
#  'http://purl.uniprot.org/uniprot/Q8IY84',
#  'http://purl.uniprot.org/uniprot/Q8IYT8',
#  'http://purl.uniprot.org/uniprot/Q8N4C8',
#  'http://purl.uniprot.org/uniprot/Q8N568',
#  'http://purl.uniprot.org/uniprot/Q8N5S9',
#  'http://purl.uniprot.org/uniprot/Q8N752',
#  'http://purl.uniprot.org/uniprot/Q8NE63',
#  'http://purl.uniprot.org/uniprot/Q8NEV4',
#  'http://purl.uniprot.org/uniprot/Q8NFD2',
#  'http://purl.uniprot.org/uniprot/Q8NG66',
#  'http://purl.uniprot.org/uniprot/Q8NI60',
#  'http://purl.uniprot.org/uniprot/Q8T9Z7',
#  'http://purl.uniprot.org/uniprot/Q8TBX8',
#  'http://purl.uniprot.org/uniprot/Q8TD08',
#  'http://purl.uniprot.org/uniprot/Q8TD19',
#  'http://purl.uniprot.org/uniprot/Q8TDC3',
#  'http://purl.uniprot.org/uniprot/Q8TDR2',
#  'http://purl.uniprot.org/uniprot/Q8TDX7',
#  'http://purl.uniprot.org/uniprot/Q8WTQ7',
#  'http://purl.uniprot.org/uniprot/Q8WU08',
#  'http://purl.uniprot.org/uniprot/Q8WXR4',
#  'http://purl.uniprot.org/uniprot/Q92630',
#  'http://purl.uniprot.org/uniprot/Q92772',
#  'http://purl.uniprot.org/uniprot/Q92918',
#  'http://purl.uniprot.org/uniprot/Q96BR1',
#  'http://purl.uniprot.org/uniprot/Q96D53',
#  'http://purl.uniprot.org/uniprot/Q96GD4',
#  'http://purl.uniprot.org/uniprot/Q96KB5',
#  'http://purl.uniprot.org/uniprot/Q96L34',
#  'http://purl.uniprot.org/uniprot/Q96NX5',
#  'http://purl.uniprot.org/uniprot/Q96PF2',
#  'http://purl.uniprot.org/uniprot/Q96PY6',
#  'http://purl.uniprot.org/uniprot/Q96Q40',
#  'http://purl.uniprot.org/uniprot/Q96RG2',
#  'http://purl.uniprot.org/uniprot/Q96RR4',
#  'http://purl.uniprot.org/uniprot/Q96SB4',
#  'http://purl.uniprot.org/uniprot/Q99640',
#  'http://purl.uniprot.org/uniprot/Q99683',
#  'http://purl.uniprot.org/uniprot/Q99755',
#  'http://purl.uniprot.org/uniprot/Q99759',
#  'http://purl.uniprot.org/uniprot/Q9BQI3',
#  'http://purl.uniprot.org/uniprot/Q9BRS2',
#  'http://purl.uniprot.org/uniprot/Q9BUB5',
#  'http://purl.uniprot.org/uniprot/Q9BVS4',
#  'http://purl.uniprot.org/uniprot/Q9BWU1',
#  'http://purl.uniprot.org/uniprot/Q9BX84',
#  'http://purl.uniprot.org/uniprot/Q9BXA7',
#  'http://purl.uniprot.org/uniprot/Q9BYT3',
#  'http://purl.uniprot.org/uniprot/Q9BZL6',
#  'http://purl.uniprot.org/uniprot/Q9C098',
#  'http://purl.uniprot.org/uniprot/Q9H093',
#  'http://purl.uniprot.org/uniprot/Q9H0K1',
#  'http://purl.uniprot.org/uniprot/Q9H1R3',
#  'http://purl.uniprot.org/uniprot/Q9H2G2',
#  'http://purl.uniprot.org/uniprot/Q9H2K2',
#  'http://purl.uniprot.org/uniprot/Q9H2K8',
#  'http://purl.uniprot.org/uniprot/Q9H2X6',
#  'http://purl.uniprot.org/uniprot/Q9H3Y6',
#  'http://purl.uniprot.org/uniprot/Q9H422',
#  'http://purl.uniprot.org/uniprot/Q9H4B4',
#  'http://purl.uniprot.org/uniprot/Q9HAZ1',
#  'http://purl.uniprot.org/uniprot/Q9HBH9',
#  'http://purl.uniprot.org/uniprot/Q9HBY8',
#  'http://purl.uniprot.org/uniprot/Q9HC98',
#  'http://purl.uniprot.org/uniprot/Q9HCP0',
#  'http://purl.uniprot.org/uniprot/Q9JI10',
#  'http://purl.uniprot.org/uniprot/Q9NQU5',
#  'http://purl.uniprot.org/uniprot/Q9NRH2',
#  'http://purl.uniprot.org/uniprot/Q9NRM7',
#  'http://purl.uniprot.org/uniprot/Q9NRP7',
#  'http://purl.uniprot.org/uniprot/Q9NSY1',
#  'http://purl.uniprot.org/uniprot/Q9NWZ3',
#  'http://purl.uniprot.org/uniprot/Q9NY57',
#  'http://purl.uniprot.org/uniprot/Q9NYL2',
#  'http://purl.uniprot.org/uniprot/Q9NYY3',
#  'http://purl.uniprot.org/uniprot/Q9P0L2',
#  'http://purl.uniprot.org/uniprot/Q9P1W9',
#  'http://purl.uniprot.org/uniprot/Q9P286',
#  'http://purl.uniprot.org/uniprot/Q9P289',
#  'http://purl.uniprot.org/uniprot/Q9P2K8',
#  'http://purl.uniprot.org/uniprot/Q9UBE8',
#  'http://purl.uniprot.org/uniprot/Q9UBF8',
#  'http://purl.uniprot.org/uniprot/Q9UEE5',
#  'http://purl.uniprot.org/uniprot/Q9UEW8',
#  'http://purl.uniprot.org/uniprot/Q9UF33',
#  'http://purl.uniprot.org/uniprot/Q9UHD2',
#  'http://purl.uniprot.org/uniprot/Q9UIK4',
#  'http://purl.uniprot.org/uniprot/Q9UK32',
#  'http://purl.uniprot.org/uniprot/Q9UKE5',
#  'http://purl.uniprot.org/uniprot/Q9UKI8',
#  'http://purl.uniprot.org/uniprot/Q9UL54',
#  'http://purl.uniprot.org/uniprot/Q9UM73',
#  'http://purl.uniprot.org/uniprot/Q9UPE1',
#  'http://purl.uniprot.org/uniprot/Q9UPZ9',
#  'http://purl.uniprot.org/uniprot/Q9UQ88',
#  'http://purl.uniprot.org/uniprot/Q9UQB9',
#  'http://purl.uniprot.org/uniprot/Q9UQM7',
#  'http://purl.uniprot.org/uniprot/Q9Y243',
#  'http://purl.uniprot.org/uniprot/Q9Y2H1',
#  'http://purl.uniprot.org/uniprot/Q9Y2H9',
#  'http://purl.uniprot.org/uniprot/Q9Y2K2',
#  'http://purl.uniprot.org/uniprot/Q9Y2U5',
#  'http://purl.uniprot.org/uniprot/Q9Y463',
#  'http://purl.uniprot.org/uniprot/Q9Y4K4',
#  'http://purl.uniprot.org/uniprot/Q9Y5S2',
#  'http://purl.uniprot.org/uniprot/Q9Y616',
#  'http://purl.uniprot.org/uniprot/Q9Y6E0',
#  'http://purl.uniprot.org/uniprot/Q9Y6M4',
#  'http://purl.uniprot.org/uniprot/Q9Y6R4'}

# %% [markdown]
# ### Map the Uniprot URIs to Nextprot URIs

# %%
def uniprot_to_nexprotid(uniprot_uri):
    uniprotid = uniprot_uri.split("http://purl.uniprot.org/uniprot/")[1]
    nxp = "http://nextprot.org/rdf/entry/NX_" + uniprotid
    return nxp

# %%
nxp_target_list = [uniprot_to_nexprotid(x) for x in target_list]

# %%
len(nxp_target_list)
# Out:
# 437

# %% [markdown]
# ### Find the tissues where each protein is highly expressed

# %%
def nextprot_highly_expressed(nextprot_uri):
    
    payload = {'entry': nextprot_uri, 'endpoint': 'https://sparql.nextprot.org/'}
    headers = {'Accept': 'application/sparql-results+json'}
    r = requests.get('http://grlc.io/api/openphacts/FederatedPhacts/nextprot-highlyExpressed', headers=headers, params=payload)
    results = r.json()
    tissues_expressed = []
    for r in results["results"]['bindings']:
        tissues_expressed.append((nextprot_uri, r['tissue']['value'], r['tisslab']['value']))
    print(nextprot_uri + " Result Count: " + str(len(tissues_expressed)))
    return tissues_expressed

# %%
display(nxp_target_list)
# Out:
# ['http://nextprot.org/rdf/entry/NX_P15735',
#  'http://nextprot.org/rdf/entry/NX_O75747',
#  'http://nextprot.org/rdf/entry/NX_P06240',
#  'http://nextprot.org/rdf/entry/NX_O00444',
#  'http://nextprot.org/rdf/entry/NX_Q06418',
#  'http://nextprot.org/rdf/entry/NX_P52333',
#  'http://nextprot.org/rdf/entry/NX_P62344',
#  'http://nextprot.org/rdf/entry/NX_P35916',
#  'http://nextprot.org/rdf/entry/NX_P00533',
#  'http://nextprot.org/rdf/entry/NX_O60563',
#  'http://nextprot.org/rdf/entry/NX_P22607',
#  'http://nextprot.org/rdf/entry/NX_P21802',
#  'http://nextprot.org/rdf/entry/NX_P54760',
#  'http://nextprot.org/rdf/entry/NX_P06213',
#  'http://nextprot.org/rdf/entry/NX_Q13546',
#  'http://nextprot.org/rdf/entry/NX_Q9NYY3',
#  'http://nextprot.org/rdf/entry/NX_Q00526',
#  'http://nextprot.org/rdf/entry/NX_P48730',
#  'http://nextprot.org/rdf/entry/NX_P54753',
#  'http://nextprot.org/rdf/entry/NX_Q16288',
#  'http://nextprot.org/rdf/entry/NX_O15146',
#  'http://nextprot.org/rdf/entry/NX_O14965',
#  'http://nextprot.org/rdf/entry/NX_Q96L34',
#  'http://nextprot.org/rdf/entry/NX_P04049',
#  'http://nextprot.org/rdf/entry/NX_Q13976',
#  'http://nextprot.org/rdf/entry/NX_P42345',
#  'http://nextprot.org/rdf/entry/NX_O43353',
#  'http://nextprot.org/rdf/entry/NX_Q03164',
#  'http://nextprot.org/rdf/entry/NX_Q6P3R8',
#  'http://nextprot.org/rdf/entry/NX_P05622',
#  'http://nextprot.org/rdf/entry/NX_P78356',
#  'http://nextprot.org/rdf/entry/NX_P52564',
#  'http://nextprot.org/rdf/entry/NX_P17612',
#  'http://nextprot.org/rdf/entry/NX_Q9UPE1',
#  'http://nextprot.org/rdf/entry/NX_Q02763',
#  'http://nextprot.org/rdf/entry/NX_Q8NEV4',
#  'http://nextprot.org/rdf/entry/NX_P28222',
#  'http://nextprot.org/rdf/entry/NX_Q9Y6M4',
#  'http://nextprot.org/rdf/entry/NX_P32298',
#  'http://nextprot.org/rdf/entry/NX_Q8TDX7',
#  'http://nextprot.org/rdf/entry/NX_P42684',
#  'http://nextprot.org/rdf/entry/NX_Q8IW41',
#  'http://nextprot.org/rdf/entry/NX_P17252',
#  'http://nextprot.org/rdf/entry/NX_Q09013',
#  'http://nextprot.org/rdf/entry/NX_P67870',
#  'http://nextprot.org/rdf/entry/NX_P42680',
#  'http://nextprot.org/rdf/entry/NX_P27448',
#  'http://nextprot.org/rdf/entry/NX_P16234',
#  'http://nextprot.org/rdf/entry/NX_O60674',
#  'http://nextprot.org/rdf/entry/NX_P35968',
#  'http://nextprot.org/rdf/entry/NX_O75582',
#  'http://nextprot.org/rdf/entry/NX_Q9H3Y6',
#  'http://nextprot.org/rdf/entry/NX_Q00534',
#  'http://nextprot.org/rdf/entry/NX_P27361',
#  'http://nextprot.org/rdf/entry/NX_Q8T9Z7',
#  'http://nextprot.org/rdf/entry/NX_P23443',
#  'http://nextprot.org/rdf/entry/NX_O75385',
#  'http://nextprot.org/rdf/entry/NX_Q6XUX3',
#  'http://nextprot.org/rdf/entry/NX_Q16816',
#  'http://nextprot.org/rdf/entry/NX_P09619',
#  'http://nextprot.org/rdf/entry/NX_Q13131',
#  'http://nextprot.org/rdf/entry/NX_Q86UX6',
#  'http://nextprot.org/rdf/entry/NX_Q9BUB5',
#  'http://nextprot.org/rdf/entry/NX_Q9BXA7',
#  'http://nextprot.org/rdf/entry/NX_Q13043',
#  'http://nextprot.org/rdf/entry/NX_O14936',
#  'http://nextprot.org/rdf/entry/NX_P11309',
#  'http://nextprot.org/rdf/entry/NX_Q99683',
#  'http://nextprot.org/rdf/entry/NX_Q9Y2H9',
#  'http://nextprot.org/rdf/entry/NX_Q9BRS2',
#  'http://nextprot.org/rdf/entry/NX_P41240',
#  'http://nextprot.org/rdf/entry/NX_Q8IVW4',
#  'http://nextprot.org/rdf/entry/NX_P24941',
#  'http://nextprot.org/rdf/entry/NX_P34969',
#  'http://nextprot.org/rdf/entry/NX_P16591',
#  'http://nextprot.org/rdf/entry/NX_P09769',
#  'http://nextprot.org/rdf/entry/NX_O95382',
#  'http://nextprot.org/rdf/entry/NX_Q16566',
#  'http://nextprot.org/rdf/entry/NX_P31152',
#  'http://nextprot.org/rdf/entry/NX_O15530',
#  'http://nextprot.org/rdf/entry/NX_Q8WU08',
#  'http://nextprot.org/rdf/entry/NX_Q8NI60',
#  'http://nextprot.org/rdf/entry/NX_P08922',
#  'http://nextprot.org/rdf/entry/NX_Q92630',
#  'http://nextprot.org/rdf/entry/NX_P30939',
#  'http://nextprot.org/rdf/entry/NX_O15111',
#  'http://nextprot.org/rdf/entry/NX_P9WI81',
#  'http://nextprot.org/rdf/entry/NX_P21127',
#  'http://nextprot.org/rdf/entry/NX_P34913',
#  'http://nextprot.org/rdf/entry/NX_Q6ZN16',
#  'http://nextprot.org/rdf/entry/NX_P21709',
#  'http://nextprot.org/rdf/entry/NX_Q8TDR2',
#  'http://nextprot.org/rdf/entry/NX_O94782',
#  'http://nextprot.org/rdf/entry/NX_P49759',
#  'http://nextprot.org/rdf/entry/NX_Q08345',
#  'http://nextprot.org/rdf/entry/NX_Q04759',
#  'http://nextprot.org/rdf/entry/NX_Q9NYL2',
#  'http://nextprot.org/rdf/entry/NX_Q12851',
#  'http://nextprot.org/rdf/entry/NX_Q96GD4',
#  'http://nextprot.org/rdf/entry/NX_P47898',
#  'http://nextprot.org/rdf/entry/NX_Q04912',
#  'http://nextprot.org/rdf/entry/NX_O15075',
#  'http://nextprot.org/rdf/entry/NX_Q9UQM7',
#  'http://nextprot.org/rdf/entry/NX_Q07912',
#  'http://nextprot.org/rdf/entry/NX_Q8IWQ3',
#  'http://nextprot.org/rdf/entry/NX_Q8N752',
#  'http://nextprot.org/rdf/entry/NX_Q9H1R3',
#  'http://nextprot.org/rdf/entry/NX_P07948',
#  'http://nextprot.org/rdf/entry/NX_P54756',
#  'http://nextprot.org/rdf/entry/NX_P45985',
#  'http://nextprot.org/rdf/entry/NX_Q06187',
#  'http://nextprot.org/rdf/entry/NX_Q99759',
#  'http://nextprot.org/rdf/entry/NX_P07947',
#  'http://nextprot.org/rdf/entry/NX_Q9UEW8',
#  'http://nextprot.org/rdf/entry/NX_P29320',
#  'http://nextprot.org/rdf/entry/NX_P0C264',
#  'http://nextprot.org/rdf/entry/NX_Q9Y2K2',
#  'http://nextprot.org/rdf/entry/NX_O96013',
#  'http://nextprot.org/rdf/entry/NX_Q12852',
#  'http://nextprot.org/rdf/entry/NX_Q86YV6',
#  'http://nextprot.org/rdf/entry/NX_Q99640',
#  'http://nextprot.org/rdf/entry/NX_Q96PF2',
#  'http://nextprot.org/rdf/entry/NX_Q04771',
#  'http://nextprot.org/rdf/entry/NX_P29597',
#  'http://nextprot.org/rdf/entry/NX_O43283',
#  'http://nextprot.org/rdf/entry/NX_P10721',
#  'http://nextprot.org/rdf/entry/NX_O75914',
#  'http://nextprot.org/rdf/entry/NX_O76039',
#  'http://nextprot.org/rdf/entry/NX_Q9NRP7',
#  'http://nextprot.org/rdf/entry/NX_O14920',
#  'http://nextprot.org/rdf/entry/NX_P42336',
#  'http://nextprot.org/rdf/entry/NX_O43318',
#  'http://nextprot.org/rdf/entry/NX_P49840',
#  'http://nextprot.org/rdf/entry/NX_P50613',
#  'http://nextprot.org/rdf/entry/NX_P50750',
#  'http://nextprot.org/rdf/entry/NX_O14733',
#  'http://nextprot.org/rdf/entry/NX_Q86UE8',
#  'http://nextprot.org/rdf/entry/NX_P80192',
#  'http://nextprot.org/rdf/entry/NX_Q96RR4',
#  'http://nextprot.org/rdf/entry/NX_O94921',
#  'http://nextprot.org/rdf/entry/NX_Q9H2K2',
#  'http://nextprot.org/rdf/entry/NX_P29350',
#  'http://nextprot.org/rdf/entry/NX_Q13153',
#  'http://nextprot.org/rdf/entry/NX_Q9UQ88',
#  'http://nextprot.org/rdf/entry/NX_Q14289',
#  'http://nextprot.org/rdf/entry/NX_Q00532',
#  'http://nextprot.org/rdf/entry/NX_P29323',
#  'http://nextprot.org/rdf/entry/NX_Q15746',
#  'http://nextprot.org/rdf/entry/NX_Q15208',
#  'http://nextprot.org/rdf/entry/NX_Q96PY6',
#  'http://nextprot.org/rdf/entry/NX_Q8WXR4',
#  'http://nextprot.org/rdf/entry/NX_P78362',
#  'http://nextprot.org/rdf/entry/NX_P45984',
#  'http://nextprot.org/rdf/entry/NX_O60331',
#  'http://nextprot.org/rdf/entry/NX_Q13555',
#  'http://nextprot.org/rdf/entry/NX_Q9NY57',
#  'http://nextprot.org/rdf/entry/NX_O14976',
#  'http://nextprot.org/rdf/entry/NX_Q14004',
#  'http://nextprot.org/rdf/entry/NX_Q9NRM7',
#  'http://nextprot.org/rdf/entry/NX_Q99755',
#  'http://nextprot.org/rdf/entry/NX_Q07002',
#  'http://nextprot.org/rdf/entry/NX_Q9Y243',
#  'http://nextprot.org/rdf/entry/NX_Q14164',
#  'http://nextprot.org/rdf/entry/NX_Q86V86',
#  'http://nextprot.org/rdf/entry/NX_Q9P0L2',
#  'http://nextprot.org/rdf/entry/NX_P28566',
#  'http://nextprot.org/rdf/entry/NX_P78368',
#  'http://nextprot.org/rdf/entry/NX_Q12866',
#  'http://nextprot.org/rdf/entry/NX_P80370',
#  'http://nextprot.org/rdf/entry/NX_P36894',
#  'http://nextprot.org/rdf/entry/NX_P51957',
#  'http://nextprot.org/rdf/entry/NX_O43293',
#  'http://nextprot.org/rdf/entry/NX_P51817',
#  'http://nextprot.org/rdf/entry/NX_P05129',
#  'http://nextprot.org/rdf/entry/NX_P37840',
#  'http://nextprot.org/rdf/entry/NX_Q15569',
#  'http://nextprot.org/rdf/entry/NX_O95819',
#  'http://nextprot.org/rdf/entry/NX_O94768',
#  'http://nextprot.org/rdf/entry/NX_P57059',
#  'http://nextprot.org/rdf/entry/NX_P41743',
#  'http://nextprot.org/rdf/entry/NX_P19784',
#  'http://nextprot.org/rdf/entry/NX_Q9NWZ3',
#  'http://nextprot.org/rdf/entry/NX_Q00536',
#  'http://nextprot.org/rdf/entry/NX_P23458',
#  'http://nextprot.org/rdf/entry/NX_Q13470',
#  'http://nextprot.org/rdf/entry/NX_Q9H4B4',
#  'http://nextprot.org/rdf/entry/NX_Q9BQI3',
#  'http://nextprot.org/rdf/entry/NX_Q8IU85',
#  'http://nextprot.org/rdf/entry/NX_Q96D53',
#  'http://nextprot.org/rdf/entry/NX_O00238',
#  'http://nextprot.org/rdf/entry/NX_P04629',
#  'http://nextprot.org/rdf/entry/NX_Q9BZL6',
#  'http://nextprot.org/rdf/entry/NX_Q14012',
#  'http://nextprot.org/rdf/entry/NX_P36888',
#  'http://nextprot.org/rdf/entry/NX_P06239',
#  'http://nextprot.org/rdf/entry/NX_Q9HC98',
#  'http://nextprot.org/rdf/entry/NX_P00519',
#  'http://nextprot.org/rdf/entry/NX_Q92918',
#  'http://nextprot.org/rdf/entry/NX_P51451',
#  'http://nextprot.org/rdf/entry/NX_Q8N4C8',
#  'http://nextprot.org/rdf/entry/NX_Q8TBX8',
#  'http://nextprot.org/rdf/entry/NX_P46734',
#  'http://nextprot.org/rdf/entry/NX_Q9HCP0',
#  'http://nextprot.org/rdf/entry/NX_Q15303',
#  'http://nextprot.org/rdf/entry/NX_Q9Y6R4',
#  'http://nextprot.org/rdf/entry/NX_Q7KZI7',
#  'http://nextprot.org/rdf/entry/NX_P28482',
#  'http://nextprot.org/rdf/entry/NX_Q05655',
#  'http://nextprot.org/rdf/entry/NX_P53350',
#  'http://nextprot.org/rdf/entry/NX_P78396',
#  'http://nextprot.org/rdf/entry/NX_O14757',
#  'http://nextprot.org/rdf/entry/NX_O75116',
#  'http://nextprot.org/rdf/entry/NX_P45983',
#  'http://nextprot.org/rdf/entry/NX_P51956',
#  'http://nextprot.org/rdf/entry/NX_P25094',
#  'http://nextprot.org/rdf/entry/NX_P29317',
#  'http://nextprot.org/rdf/entry/NX_Q13164',
#  'http://nextprot.org/rdf/entry/NX_P14616',
#  'http://nextprot.org/rdf/entry/NX_Q13557',
#  'http://nextprot.org/rdf/entry/NX_Q9UHD2',
#  'http://nextprot.org/rdf/entry/NX_P35590',
#  'http://nextprot.org/rdf/entry/NX_P42681',
#  'http://nextprot.org/rdf/entry/NX_O00329',
#  'http://nextprot.org/rdf/entry/NX_Q52WX2',
#  'http://nextprot.org/rdf/entry/NX_P36896',
#  'http://nextprot.org/rdf/entry/NX_P42679',
#  'http://nextprot.org/rdf/entry/NX_P36897',
#  'http://nextprot.org/rdf/entry/NX_Q6PHR2',
#  'http://nextprot.org/rdf/entry/NX_Q9UKI8',
#  'http://nextprot.org/rdf/entry/NX_P15056',
#  'http://nextprot.org/rdf/entry/NX_P84022',
#  'http://nextprot.org/rdf/entry/NX_O15264',
#  'http://nextprot.org/rdf/entry/NX_Q9HBY8',
#  'http://nextprot.org/rdf/entry/NX_Q13464',
#  'http://nextprot.org/rdf/entry/NX_Q08881',
#  'http://nextprot.org/rdf/entry/NX_P06241',
#  'http://nextprot.org/rdf/entry/NX_P07949',
#  'http://nextprot.org/rdf/entry/NX_P37173',
#  'http://nextprot.org/rdf/entry/NX_Q15831',
#  'http://nextprot.org/rdf/entry/NX_Q9UKE5',
#  'http://nextprot.org/rdf/entry/NX_Q9UBF8',
#  'http://nextprot.org/rdf/entry/NX_Q8TD19',
#  'http://nextprot.org/rdf/entry/NX_Q8IY84',
#  'http://nextprot.org/rdf/entry/NX_Q8NE63',
#  'http://nextprot.org/rdf/entry/NX_Q15375',
#  'http://nextprot.org/rdf/entry/NX_P53667',
#  'http://nextprot.org/rdf/entry/NX_Q16513',
#  'http://nextprot.org/rdf/entry/NX_P00523',
#  'http://nextprot.org/rdf/entry/NX_P22694',
#  'http://nextprot.org/rdf/entry/NX_Q8WTQ7',
#  'http://nextprot.org/rdf/entry/NX_O15648',
#  'http://nextprot.org/rdf/entry/NX_Q8N568',
#  'http://nextprot.org/rdf/entry/NX_Q8TDC3',
#  'http://nextprot.org/rdf/entry/NX_Q13188',
#  'http://nextprot.org/rdf/entry/NX_P20248',
#  'http://nextprot.org/rdf/entry/NX_Q96SB4',
#  'http://nextprot.org/rdf/entry/NX_Q2M2I8',
#  'http://nextprot.org/rdf/entry/NX_P37023',
#  'http://nextprot.org/rdf/entry/NX_P48729',
#  'http://nextprot.org/rdf/entry/NX_Q32MK0',
#  'http://nextprot.org/rdf/entry/NX_Q9H0K1',
#  'http://nextprot.org/rdf/entry/NX_Q9NRH2',
#  'http://nextprot.org/rdf/entry/NX_P30530',
#  'http://nextprot.org/rdf/entry/NX_Q9P289',
#  'http://nextprot.org/rdf/entry/NX_P53355',
#  'http://nextprot.org/rdf/entry/NX_P20794',
#  'http://nextprot.org/rdf/entry/NX_P36507',
#  'http://nextprot.org/rdf/entry/NX_P49761',
#  'http://nextprot.org/rdf/entry/NX_Q13237',
#  'http://nextprot.org/rdf/entry/NX_Q86Z02',
#  'http://nextprot.org/rdf/entry/NX_Q00537',
#  'http://nextprot.org/rdf/entry/NX_P0C1S8',
#  'http://nextprot.org/rdf/entry/NX_Q02750',
#  'http://nextprot.org/rdf/entry/NX_P08908',
#  'http://nextprot.org/rdf/entry/NX_O75496',
#  'http://nextprot.org/rdf/entry/NX_P49674',
#  'http://nextprot.org/rdf/entry/NX_P07332',
#  'http://nextprot.org/rdf/entry/NX_P24723',
#  'http://nextprot.org/rdf/entry/NX_Q96KB5',
#  'http://nextprot.org/rdf/entry/NX_Q96BR1',
#  'http://nextprot.org/rdf/entry/NX_P51955',
#  'http://nextprot.org/rdf/entry/NX_P30291',
#  'http://nextprot.org/rdf/entry/NX_Q9H422',
#  'http://nextprot.org/rdf/entry/NX_Q9Y5S2',
#  'http://nextprot.org/rdf/entry/NX_P54646',
#  'http://nextprot.org/rdf/entry/NX_P42338',
#  'http://nextprot.org/rdf/entry/NX_P04626',
#  'http://nextprot.org/rdf/entry/NX_P06493',
#  'http://nextprot.org/rdf/entry/NX_P54764',
#  'http://nextprot.org/rdf/entry/NX_Q9Y2U5',
#  'http://nextprot.org/rdf/entry/NX_Q14680',
#  'http://nextprot.org/rdf/entry/NX_Q9Y463',
#  'http://nextprot.org/rdf/entry/NX_P49137',
#  'http://nextprot.org/rdf/entry/NX_Q02779',
#  'http://nextprot.org/rdf/entry/NX_Q9UM73',
#  'http://nextprot.org/rdf/entry/NX_Q9H093',
#  'http://nextprot.org/rdf/entry/NX_Q9UK32',
#  'http://nextprot.org/rdf/entry/NX_Q6DT37',
#  'http://nextprot.org/rdf/entry/NX_Q9UL54',
#  'http://nextprot.org/rdf/entry/NX_P12931',
#  'http://nextprot.org/rdf/entry/NX_Q15835',
#  'http://nextprot.org/rdf/entry/NX_O60285',
#  'http://nextprot.org/rdf/entry/NX_P53671',
#  'http://nextprot.org/rdf/entry/NX_P49841',
#  'http://nextprot.org/rdf/entry/NX_Q92772',
#  'http://nextprot.org/rdf/entry/NX_Q9UF33',
#  'http://nextprot.org/rdf/entry/NX_P21860',
#  'http://nextprot.org/rdf/entry/NX_Q9JI10',
#  'http://nextprot.org/rdf/entry/NX_O75676',
#  'http://nextprot.org/rdf/entry/NX_Q9UIK4',
#  'http://nextprot.org/rdf/entry/NX_P53778',
#  'http://nextprot.org/rdf/entry/NX_P07333',
#  'http://nextprot.org/rdf/entry/NX_Q13705',
#  'http://nextprot.org/rdf/entry/NX_Q16620',
#  'http://nextprot.org/rdf/entry/NX_Q9H2K8',
#  'http://nextprot.org/rdf/entry/NX_Q5S007',
#  'http://nextprot.org/rdf/entry/NX_P28335',
#  'http://nextprot.org/rdf/entry/NX_P54762',
#  'http://nextprot.org/rdf/entry/NX_P48736',
#  'http://nextprot.org/rdf/entry/NX_Q59H18',
#  'http://nextprot.org/rdf/entry/NX_Q15139',
#  'http://nextprot.org/rdf/entry/NX_Q9HAZ1',
#  'http://nextprot.org/rdf/entry/NX_P49336',
#  'http://nextprot.org/rdf/entry/NX_P08581',
#  'http://nextprot.org/rdf/entry/NX_Q9BX84',
#  'http://nextprot.org/rdf/entry/NX_O95835',
#  'http://nextprot.org/rdf/entry/NX_P34947',
#  'http://nextprot.org/rdf/entry/NX_P08069',
#  'http://nextprot.org/rdf/entry/NX_P11799',
#  'http://nextprot.org/rdf/entry/NX_O75716',
#  'http://nextprot.org/rdf/entry/NX_Q9UBE8',
#  'http://nextprot.org/rdf/entry/NX_Q13233',
#  'http://nextprot.org/rdf/entry/NX_O00141',
#  'http://nextprot.org/rdf/entry/NX_Q9UPZ9',
#  'http://nextprot.org/rdf/entry/NX_Q9P2K8',
#  'http://nextprot.org/rdf/entry/NX_P42685',
#  'http://nextprot.org/rdf/entry/NX_Q9H2G2',
#  'http://nextprot.org/rdf/entry/NX_Q96RG2',
#  'http://nextprot.org/rdf/entry/NX_Q02156',
#  'http://nextprot.org/rdf/entry/NX_P51812',
#  'http://nextprot.org/rdf/entry/NX_Q16644',
#  'http://nextprot.org/rdf/entry/NX_P24385',
#  'http://nextprot.org/rdf/entry/NX_Q16659',
#  'http://nextprot.org/rdf/entry/NX_P68400',
#  'http://nextprot.org/rdf/entry/NX_P00520',
#  'http://nextprot.org/rdf/entry/NX_Q86Y07',
#  'http://nextprot.org/rdf/entry/NX_Q9H2X6',
#  'http://nextprot.org/rdf/entry/NX_Q56UN5',
#  'http://nextprot.org/rdf/entry/NX_Q9Y6E0',
#  'http://nextprot.org/rdf/entry/NX_O14578',
#  'http://nextprot.org/rdf/entry/NX_P57078',
#  'http://nextprot.org/rdf/entry/NX_P31749',
#  'http://nextprot.org/rdf/entry/NX_P78527',
#  'http://nextprot.org/rdf/entry/NX_P33981',
#  'http://nextprot.org/rdf/entry/NX_P41595',
#  'http://nextprot.org/rdf/entry/NX_P43405',
#  'http://nextprot.org/rdf/entry/NX_Q9NSY1',
#  'http://nextprot.org/rdf/entry/NX_Q9P286',
#  'http://nextprot.org/rdf/entry/NX_O43172',
#  'http://nextprot.org/rdf/entry/NX_O43781',
#  'http://nextprot.org/rdf/entry/NX_Q13177',
#  'http://nextprot.org/rdf/entry/NX_P53779',
#  'http://nextprot.org/rdf/entry/NX_Q8N5S9',
#  'http://nextprot.org/rdf/entry/NX_O00255',
#  'http://nextprot.org/rdf/entry/NX_Q96NX5',
#  'http://nextprot.org/rdf/entry/NX_P11274',
#  'http://nextprot.org/rdf/entry/NX_P43403',
#  'http://nextprot.org/rdf/entry/NX_Q13882',
#  'http://nextprot.org/rdf/entry/NX_Q8TD08',
#  'http://nextprot.org/rdf/entry/NX_P29322',
#  'http://nextprot.org/rdf/entry/NX_O15197',
#  'http://nextprot.org/rdf/entry/NX_Q9Y616',
#  'http://nextprot.org/rdf/entry/NX_Q8IVH8',
#  'http://nextprot.org/rdf/entry/NX_Q9BWU1',
#  'http://nextprot.org/rdf/entry/NX_P51617',
#  'http://nextprot.org/rdf/entry/NX_Q96Q40',
#  'http://nextprot.org/rdf/entry/NX_Q13163',
#  'http://nextprot.org/rdf/entry/NX_Q9UEE5',
#  'http://nextprot.org/rdf/entry/NX_Q9C098',
#  'http://nextprot.org/rdf/entry/NX_O95747',
#  'http://nextprot.org/rdf/entry/NX_Q13554',
#  'http://nextprot.org/rdf/entry/NX_P51450',
#  'http://nextprot.org/rdf/entry/NX_Q5GIT4',
#  'http://nextprot.org/rdf/entry/NX_O94806',
#  'http://nextprot.org/rdf/entry/NX_Q9Y2H1',
#  'http://nextprot.org/rdf/entry/NX_P51813',
#  'http://nextprot.org/rdf/entry/NX_P17948',
#  'http://nextprot.org/rdf/entry/NX_Q13627',
#  'http://nextprot.org/rdf/entry/NX_O96017',
#  'http://nextprot.org/rdf/entry/NX_Q00535',
#  'http://nextprot.org/rdf/entry/NX_Q15349',
#  'http://nextprot.org/rdf/entry/NX_Q9UQB9',
#  'http://nextprot.org/rdf/entry/NX_P08631',
#  'http://nextprot.org/rdf/entry/NX_Q16512',
#  'http://nextprot.org/rdf/entry/NX_P29376',
#  'http://nextprot.org/rdf/entry/NX_O14730',
#  'http://nextprot.org/rdf/entry/NX_Q13523',
#  'http://nextprot.org/rdf/entry/NX_Q16584',
#  'http://nextprot.org/rdf/entry/NX_P27037',
#  'http://nextprot.org/rdf/entry/NX_Q16832',
#  'http://nextprot.org/rdf/entry/NX_P19525',
#  'http://nextprot.org/rdf/entry/NX_Q9P1W9',
#  'http://nextprot.org/rdf/entry/NX_O75460',
#  'http://nextprot.org/rdf/entry/NX_Q05513',
#  'http://nextprot.org/rdf/entry/NX_P57058',
#  'http://nextprot.org/rdf/entry/NX_P28223',
#  'http://nextprot.org/rdf/entry/NX_P11362',
#  'http://nextprot.org/rdf/entry/NX_Q8IYT8',
#  'http://nextprot.org/rdf/entry/NX_O94804',
#  'http://nextprot.org/rdf/entry/NX_Q9Y4K4',
#  'http://nextprot.org/rdf/entry/NX_Q7L7X3',
#  'http://nextprot.org/rdf/entry/NX_Q9BYT3',
#  'http://nextprot.org/rdf/entry/NX_Q8NFD2',
#  'http://nextprot.org/rdf/entry/NX_P68370',
#  'http://nextprot.org/rdf/entry/NX_Q16539',
#  'http://nextprot.org/rdf/entry/NX_Q9NQU5',
#  'http://nextprot.org/rdf/entry/NX_Q15418',
#  'http://nextprot.org/rdf/entry/NX_Q5VT25',
#  'http://nextprot.org/rdf/entry/NX_O75909',
#  'http://nextprot.org/rdf/entry/NX_O00311',
#  'http://nextprot.org/rdf/entry/NX_P61075',
#  'http://nextprot.org/rdf/entry/NX_P11802',
#  'http://nextprot.org/rdf/entry/NX_O00418',
#  'http://nextprot.org/rdf/entry/NX_Q8NG66',
#  'http://nextprot.org/rdf/entry/NX_O00506',
#  'http://nextprot.org/rdf/entry/NX_P46098',
#  'http://nextprot.org/rdf/entry/NX_Q9BVS4',
#  'http://nextprot.org/rdf/entry/NX_O00750',
#  'http://nextprot.org/rdf/entry/NX_Q3U3Q1',
#  'http://nextprot.org/rdf/entry/NX_P22455',
#  'http://nextprot.org/rdf/entry/NX_Q13873',
#  'http://nextprot.org/rdf/entry/NX_P31751',
#  'http://nextprot.org/rdf/entry/NX_P50406',
#  'http://nextprot.org/rdf/entry/NX_Q05397',
#  'http://nextprot.org/rdf/entry/NX_Q15759',
#  'http://nextprot.org/rdf/entry/NX_P49760',
#  'http://nextprot.org/rdf/entry/NX_Q9HBH9']

# %%
tissue_results = [nextprot_highly_expressed(x) for x in nxp_target_list]
# Out:
# http://nextprot.org/rdf/entry/NX_P15735 Result Count: 1
# http://nextprot.org/rdf/entry/NX_O75747 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P06240 Result Count: 0
# http://nextprot.org/rdf/entry/NX_O00444 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q06418 Result Count: 2
# http://nextprot.org/rdf/entry/NX_P52333 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P62344 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P35916 Result Count: 1
# http://nextprot.org/rdf/entry/NX_P00533 Result Count: 3
# http://nextprot.org/rdf/entry/NX_O60563 Result Count: 4
# http://nextprot.org/rdf/entry/NX_P22607 Result Count: 2
# http://nextprot.org/rdf/entry/NX_P21802 Result Count: 8
# http://nextprot.org/rdf/entry/NX_P54760 Result Count: 2
# http://nextprot.org/rdf/entry/NX_P06213 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q13546 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q9NYY3 Result Count: 8
# http://nextprot.org/rdf/entry/NX_Q00526 Result Count: 1
# http://nextprot.org/rdf/entry/NX_P48730 Result Count: 14
# http://nextprot.org/rdf/entry/NX_P54753 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q16288 Result Count: 1
# http://nextprot.org/rdf/entry/NX_O15146 Result Count: 0
# http://nextprot.org/rdf/entry/NX_O14965 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q96L34 Result Count: 1
# http://nextprot.org/rdf/entry/NX_P04049 Result Count: 16
# http://nextprot.org/rdf/entry/NX_Q13976 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P42345 Result Count: 2
# http://nextprot.org/rdf/entry/NX_O43353 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q03164 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q6P3R8 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P05622 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P78356 Result Count: 1
# http://nextprot.org/rdf/entry/NX_P52564 Result Count: 1
# http://nextprot.org/rdf/entry/NX_P17612 Result Count: 28
# http://nextprot.org/rdf/entry/NX_Q9UPE1 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q02763 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q8NEV4 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P28222 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q9Y6M4 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P32298 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q8TDX7 Result Count: 7
# http://nextprot.org/rdf/entry/NX_P42684 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q8IW41 Result Count: 2
# http://nextprot.org/rdf/entry/NX_P17252 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q09013 Result Count: 7
# http://nextprot.org/rdf/entry/NX_P67870 Result Count: 2
# http://nextprot.org/rdf/entry/NX_P42680 Result Count: 2
# http://nextprot.org/rdf/entry/NX_P27448 Result Count: 8
# http://nextprot.org/rdf/entry/NX_P16234 Result Count: 11
# http://nextprot.org/rdf/entry/NX_O60674 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P35968 Result Count: 3
# http://nextprot.org/rdf/entry/NX_O75582 Result Count: 4
# http://nextprot.org/rdf/entry/NX_Q9H3Y6 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q00534 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P27361 Result Count: 26
# http://nextprot.org/rdf/entry/NX_Q8T9Z7 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P23443 Result Count: 2
# http://nextprot.org/rdf/entry/NX_O75385 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q6XUX3 Result Count: 15
# http://nextprot.org/rdf/entry/NX_Q16816 Result Count: 1
# http://nextprot.org/rdf/entry/NX_P09619 Result Count: 11
# http://nextprot.org/rdf/entry/NX_Q13131 Result Count: 5
# http://nextprot.org/rdf/entry/NX_Q86UX6 Result Count: 2
# http://nextprot.org/rdf/entry/NX_Q9BUB5 Result Count: 3
# http://nextprot.org/rdf/entry/NX_Q9BXA7 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q13043 Result Count: 3
# http://nextprot.org/rdf/entry/NX_O14936 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P11309 Result Count: 8
# http://nextprot.org/rdf/entry/NX_Q99683 Result Count: 5
# http://nextprot.org/rdf/entry/NX_Q9Y2H9 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q9BRS2 Result Count: 1
# http://nextprot.org/rdf/entry/NX_P41240 Result Count: 5
# http://nextprot.org/rdf/entry/NX_Q8IVW4 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P24941 Result Count: 1
# http://nextprot.org/rdf/entry/NX_P34969 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P16591 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P09769 Result Count: 4
# http://nextprot.org/rdf/entry/NX_O95382 Result Count: 3
# http://nextprot.org/rdf/entry/NX_Q16566 Result Count: 1
# http://nextprot.org/rdf/entry/NX_P31152 Result Count: 1
# http://nextprot.org/rdf/entry/NX_O15530 Result Count: 2
# http://nextprot.org/rdf/entry/NX_Q8WU08 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q8NI60 Result Count: 3
# http://nextprot.org/rdf/entry/NX_P08922 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q92630 Result Count: 1
# http://nextprot.org/rdf/entry/NX_P30939 Result Count: 0
# http://nextprot.org/rdf/entry/NX_O15111 Result Count: 2
# http://nextprot.org/rdf/entry/NX_P9WI81 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P21127 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P34913 Result Count: 15
# http://nextprot.org/rdf/entry/NX_Q6ZN16 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P21709 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q8TDR2 Result Count: 0
# http://nextprot.org/rdf/entry/NX_O94782 Result Count: 2
# http://nextprot.org/rdf/entry/NX_P49759 Result Count: 16
# http://nextprot.org/rdf/entry/NX_Q08345 Result Count: 5
# http://nextprot.org/rdf/entry/NX_Q04759 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q9NYL2 Result Count: 12
# http://nextprot.org/rdf/entry/NX_Q12851 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q96GD4 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P47898 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q04912 Result Count: 3
# http://nextprot.org/rdf/entry/NX_O15075 Result Count: 3
# http://nextprot.org/rdf/entry/NX_Q9UQM7 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q07912 Result Count: 4
# http://nextprot.org/rdf/entry/NX_Q8IWQ3 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q8N752 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q9H1R3 Result Count: 1
# http://nextprot.org/rdf/entry/NX_P07948 Result Count: 9
# http://nextprot.org/rdf/entry/NX_P54756 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P45985 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q06187 Result Count: 6
# http://nextprot.org/rdf/entry/NX_Q99759 Result Count: 1
# http://nextprot.org/rdf/entry/NX_P07947 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q9UEW8 Result Count: 1
# http://nextprot.org/rdf/entry/NX_P29320 Result Count: 1
# http://nextprot.org/rdf/entry/NX_P0C264 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q9Y2K2 Result Count: 18
# http://nextprot.org/rdf/entry/NX_O96013 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q12852 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q86YV6 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q99640 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q96PF2 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q04771 Result Count: 2
# http://nextprot.org/rdf/entry/NX_P29597 Result Count: 9
# http://nextprot.org/rdf/entry/NX_O43283 Result Count: 1
# http://nextprot.org/rdf/entry/NX_P10721 Result Count: 3
# http://nextprot.org/rdf/entry/NX_O75914 Result Count: 0
# http://nextprot.org/rdf/entry/NX_O76039 Result Count: 4
# http://nextprot.org/rdf/entry/NX_Q9NRP7 Result Count: 5
# http://nextprot.org/rdf/entry/NX_O14920 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P42336 Result Count: 4
# http://nextprot.org/rdf/entry/NX_O43318 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P49840 Result Count: 10
# http://nextprot.org/rdf/entry/NX_P50613 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P50750 Result Count: 21
# http://nextprot.org/rdf/entry/NX_O14733 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q86UE8 Result Count: 1
# http://nextprot.org/rdf/entry/NX_P80192 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q96RR4 Result Count: 1
# http://nextprot.org/rdf/entry/NX_O94921 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q9H2K2 Result Count: 1
# http://nextprot.org/rdf/entry/NX_P29350 Result Count: 8
# http://nextprot.org/rdf/entry/NX_Q13153 Result Count: 4
# http://nextprot.org/rdf/entry/NX_Q9UQ88 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q14289 Result Count: 6
# http://nextprot.org/rdf/entry/NX_Q00532 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P29323 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q15746 Result Count: 26
# http://nextprot.org/rdf/entry/NX_Q15208 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q96PY6 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q8WXR4 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P78362 Result Count: 3
# http://nextprot.org/rdf/entry/NX_P45984 Result Count: 6
# http://nextprot.org/rdf/entry/NX_O60331 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q13555 Result Count: 3
# http://nextprot.org/rdf/entry/NX_Q9NY57 Result Count: 0
# http://nextprot.org/rdf/entry/NX_O14976 Result Count: 2
# http://nextprot.org/rdf/entry/NX_Q14004 Result Count: 2
# http://nextprot.org/rdf/entry/NX_Q9NRM7 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q99755 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q07002 Result Count: 2
# http://nextprot.org/rdf/entry/NX_Q9Y243 Result Count: 2
# http://nextprot.org/rdf/entry/NX_Q14164 Result Count: 4
# http://nextprot.org/rdf/entry/NX_Q86V86 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q9P0L2 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P28566 Result Count: 4
# http://nextprot.org/rdf/entry/NX_P78368 Result Count: 3
# http://nextprot.org/rdf/entry/NX_Q12866 Result Count: 3
# http://nextprot.org/rdf/entry/NX_P80370 Result Count: 4
# http://nextprot.org/rdf/entry/NX_P36894 Result Count: 1
# http://nextprot.org/rdf/entry/NX_P51957 Result Count: 2
# http://nextprot.org/rdf/entry/NX_O43293 Result Count: 9
# http://nextprot.org/rdf/entry/NX_P51817 Result Count: 15
# http://nextprot.org/rdf/entry/NX_P05129 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P37840 Result Count: 5
# http://nextprot.org/rdf/entry/NX_Q15569 Result Count: 0
# http://nextprot.org/rdf/entry/NX_O95819 Result Count: 8
# http://nextprot.org/rdf/entry/NX_O94768 Result Count: 5
# http://nextprot.org/rdf/entry/NX_P57059 Result Count: 9
# http://nextprot.org/rdf/entry/NX_P41743 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P19784 Result Count: 3
# http://nextprot.org/rdf/entry/NX_Q9NWZ3 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q00536 Result Count: 14
# http://nextprot.org/rdf/entry/NX_P23458 Result Count: 25
# http://nextprot.org/rdf/entry/NX_Q13470 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q9H4B4 Result Count: 2
# http://nextprot.org/rdf/entry/NX_Q9BQI3 Result Count: 7
# http://nextprot.org/rdf/entry/NX_Q8IU85 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q96D53 Result Count: 3
# http://nextprot.org/rdf/entry/NX_O00238 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P04629 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q9BZL6 Result Count: 2
# http://nextprot.org/rdf/entry/NX_Q14012 Result Count: 5
# http://nextprot.org/rdf/entry/NX_P36888 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P06239 Result Count: 6
# http://nextprot.org/rdf/entry/NX_Q9HC98 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P00519 Result Count: 7
# http://nextprot.org/rdf/entry/NX_Q92918 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P51451 Result Count: 3
# http://nextprot.org/rdf/entry/NX_Q8N4C8 Result Count: 3
# http://nextprot.org/rdf/entry/NX_Q8TBX8 Result Count: 3
# http://nextprot.org/rdf/entry/NX_P46734 Result Count: 2
# http://nextprot.org/rdf/entry/NX_Q9HCP0 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q15303 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q9Y6R4 Result Count: 9
# http://nextprot.org/rdf/entry/NX_Q7KZI7 Result Count: 3
# http://nextprot.org/rdf/entry/NX_P28482 Result Count: 5
# http://nextprot.org/rdf/entry/NX_Q05655 Result Count: 14
# http://nextprot.org/rdf/entry/NX_P53350 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P78396 Result Count: 2
# http://nextprot.org/rdf/entry/NX_O14757 Result Count: 2
# http://nextprot.org/rdf/entry/NX_O75116 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P45983 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P51956 Result Count: 1
# http://nextprot.org/rdf/entry/NX_P25094 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P29317 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q13164 Result Count: 3
# http://nextprot.org/rdf/entry/NX_P14616 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q13557 Result Count: 5
# http://nextprot.org/rdf/entry/NX_Q9UHD2 Result Count: 1
# http://nextprot.org/rdf/entry/NX_P35590 Result Count: 1
# http://nextprot.org/rdf/entry/NX_P42681 Result Count: 0
# http://nextprot.org/rdf/entry/NX_O00329 Result Count: 2
# http://nextprot.org/rdf/entry/NX_Q52WX2 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P36896 Result Count: 1
# http://nextprot.org/rdf/entry/NX_P42679 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P36897 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q6PHR2 Result Count: 2
# http://nextprot.org/rdf/entry/NX_Q9UKI8 Result Count: 16
# http://nextprot.org/rdf/entry/NX_P15056 Result Count: 12
# http://nextprot.org/rdf/entry/NX_P84022 Result Count: 1
# http://nextprot.org/rdf/entry/NX_O15264 Result Count: 11
# http://nextprot.org/rdf/entry/NX_Q9HBY8 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q13464 Result Count: 6
# http://nextprot.org/rdf/entry/NX_Q08881 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P06241 Result Count: 13
# http://nextprot.org/rdf/entry/NX_P07949 Result Count: 3
# http://nextprot.org/rdf/entry/NX_P37173 Result Count: 26
# http://nextprot.org/rdf/entry/NX_Q15831 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q9UKE5 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q9UBF8 Result Count: 18
# http://nextprot.org/rdf/entry/NX_Q8TD19 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q8IY84 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q8NE63 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q15375 Result Count: 1
# http://nextprot.org/rdf/entry/NX_P53667 Result Count: 4
# http://nextprot.org/rdf/entry/NX_Q16513 Result Count: 6
# http://nextprot.org/rdf/entry/NX_P00523 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P22694 Result Count: 8
# http://nextprot.org/rdf/entry/NX_Q8WTQ7 Result Count: 0
# http://nextprot.org/rdf/entry/NX_O15648 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q8N568 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q8TDC3 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q13188 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P20248 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q96SB4 Result Count: 6
# http://nextprot.org/rdf/entry/NX_Q2M2I8 Result Count: 2
# http://nextprot.org/rdf/entry/NX_P37023 Result Count: 5
# http://nextprot.org/rdf/entry/NX_P48729 Result Count: 35
# http://nextprot.org/rdf/entry/NX_Q32MK0 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q9H0K1 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q9NRH2 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P30530 Result Count: 3
# http://nextprot.org/rdf/entry/NX_Q9P289 Result Count: 4
# http://nextprot.org/rdf/entry/NX_P53355 Result Count: 3
# http://nextprot.org/rdf/entry/NX_P20794 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P36507 Result Count: 29
# http://nextprot.org/rdf/entry/NX_P49761 Result Count: 7
# http://nextprot.org/rdf/entry/NX_Q13237 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q86Z02 Result Count: 4
# http://nextprot.org/rdf/entry/NX_Q00537 Result Count: 8
# http://nextprot.org/rdf/entry/NX_P0C1S8 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q02750 Result Count: 7
# http://nextprot.org/rdf/entry/NX_P08908 Result Count: 2
# http://nextprot.org/rdf/entry/NX_O75496 Result Count: 3
# http://nextprot.org/rdf/entry/NX_P49674 Result Count: 23
# http://nextprot.org/rdf/entry/NX_P07332 Result Count: 10
# http://nextprot.org/rdf/entry/NX_P24723 Result Count: 6
# http://nextprot.org/rdf/entry/NX_Q96KB5 Result Count: 2
# http://nextprot.org/rdf/entry/NX_Q96BR1 Result Count: 1
# http://nextprot.org/rdf/entry/NX_P51955 Result Count: 1
# http://nextprot.org/rdf/entry/NX_P30291 Result Count: 6
# http://nextprot.org/rdf/entry/NX_Q9H422 Result Count: 6
# http://nextprot.org/rdf/entry/NX_Q9Y5S2 Result Count: 4
# http://nextprot.org/rdf/entry/NX_P54646 Result Count: 1
# http://nextprot.org/rdf/entry/NX_P42338 Result Count: 1
# http://nextprot.org/rdf/entry/NX_P04626 Result Count: 16
# http://nextprot.org/rdf/entry/NX_P06493 Result Count: 1
# http://nextprot.org/rdf/entry/NX_P54764 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q9Y2U5 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q14680 Result Count: 8
# http://nextprot.org/rdf/entry/NX_Q9Y463 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P49137 Result Count: 22
# http://nextprot.org/rdf/entry/NX_Q02779 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q9UM73 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q9H093 Result Count: 2
# http://nextprot.org/rdf/entry/NX_Q9UK32 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q6DT37 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q9UL54 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P12931 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q15835 Result Count: 0
# http://nextprot.org/rdf/entry/NX_O60285 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P53671 Result Count: 5
# http://nextprot.org/rdf/entry/NX_P49841 Result Count: 2
# http://nextprot.org/rdf/entry/NX_Q92772 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q9UF33 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P21860 Result Count: 14
# http://nextprot.org/rdf/entry/NX_Q9JI10 Result Count: 0
# http://nextprot.org/rdf/entry/NX_O75676 Result Count: 5
# http://nextprot.org/rdf/entry/NX_Q9UIK4 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P53778 Result Count: 1
# http://nextprot.org/rdf/entry/NX_P07333 Result Count: 9
# http://nextprot.org/rdf/entry/NX_Q13705 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q16620 Result Count: 4
# http://nextprot.org/rdf/entry/NX_Q9H2K8 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q5S007 Result Count: 2
# http://nextprot.org/rdf/entry/NX_P28335 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P54762 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P48736 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q59H18 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q15139 Result Count: 2
# http://nextprot.org/rdf/entry/NX_Q9HAZ1 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P49336 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P08581 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q9BX84 Result Count: 0
# http://nextprot.org/rdf/entry/NX_O95835 Result Count: 2
# http://nextprot.org/rdf/entry/NX_P34947 Result Count: 2
# http://nextprot.org/rdf/entry/NX_P08069 Result Count: 1
# http://nextprot.org/rdf/entry/NX_P11799 Result Count: 0
# http://nextprot.org/rdf/entry/NX_O75716 Result Count: 2
# http://nextprot.org/rdf/entry/NX_Q9UBE8 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q13233 Result Count: 1
# http://nextprot.org/rdf/entry/NX_O00141 Result Count: 28
# http://nextprot.org/rdf/entry/NX_Q9UPZ9 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q9P2K8 Result Count: 2
# http://nextprot.org/rdf/entry/NX_P42685 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q9H2G2 Result Count: 2
# http://nextprot.org/rdf/entry/NX_Q96RG2 Result Count: 11
# http://nextprot.org/rdf/entry/NX_Q02156 Result Count: 1
# http://nextprot.org/rdf/entry/NX_P51812 Result Count: 12
# http://nextprot.org/rdf/entry/NX_Q16644 Result Count: 6
# http://nextprot.org/rdf/entry/NX_P24385 Result Count: 11
# http://nextprot.org/rdf/entry/NX_Q16659 Result Count: 3
# http://nextprot.org/rdf/entry/NX_P68400 Result Count: 16
# http://nextprot.org/rdf/entry/NX_P00520 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q86Y07 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q9H2X6 Result Count: 8
# http://nextprot.org/rdf/entry/NX_Q56UN5 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q9Y6E0 Result Count: 30
# http://nextprot.org/rdf/entry/NX_O14578 Result Count: 1
# http://nextprot.org/rdf/entry/NX_P57078 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P31749 Result Count: 39
# http://nextprot.org/rdf/entry/NX_P78527 Result Count: 18
# http://nextprot.org/rdf/entry/NX_P33981 Result Count: 2
# http://nextprot.org/rdf/entry/NX_P41595 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P43405 Result Count: 8
# http://nextprot.org/rdf/entry/NX_Q9NSY1 Result Count: 7
# http://nextprot.org/rdf/entry/NX_Q9P286 Result Count: 0
# http://nextprot.org/rdf/entry/NX_O43172 Result Count: 8
# http://nextprot.org/rdf/entry/NX_O43781 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q13177 Result Count: 2
# http://nextprot.org/rdf/entry/NX_P53779 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q8N5S9 Result Count: 1
# http://nextprot.org/rdf/entry/NX_O00255 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q96NX5 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P11274 Result Count: 2
# http://nextprot.org/rdf/entry/NX_P43403 Result Count: 2
# http://nextprot.org/rdf/entry/NX_Q13882 Result Count: 3
# http://nextprot.org/rdf/entry/NX_Q8TD08 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P29322 Result Count: 0
# http://nextprot.org/rdf/entry/NX_O15197 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q9Y616 Result Count: 2
# http://nextprot.org/rdf/entry/NX_Q8IVH8 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q9BWU1 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P51617 Result Count: 6
# http://nextprot.org/rdf/entry/NX_Q96Q40 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q13163 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q9UEE5 Result Count: 7
# http://nextprot.org/rdf/entry/NX_Q9C098 Result Count: 0
# http://nextprot.org/rdf/entry/NX_O95747 Result Count: 3
# http://nextprot.org/rdf/entry/NX_Q13554 Result Count: 1
# http://nextprot.org/rdf/entry/NX_P51450 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q5GIT4 Result Count: 0
# http://nextprot.org/rdf/entry/NX_O94806 Result Count: 2
# http://nextprot.org/rdf/entry/NX_Q9Y2H1 Result Count: 1
# http://nextprot.org/rdf/entry/NX_P51813 Result Count: 1
# http://nextprot.org/rdf/entry/NX_P17948 Result Count: 3
# http://nextprot.org/rdf/entry/NX_Q13627 Result Count: 4
# http://nextprot.org/rdf/entry/NX_O96017 Result Count: 3
# http://nextprot.org/rdf/entry/NX_Q00535 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q15349 Result Count: 3
# http://nextprot.org/rdf/entry/NX_Q9UQB9 Result Count: 1
# http://nextprot.org/rdf/entry/NX_P08631 Result Count: 3
# http://nextprot.org/rdf/entry/NX_Q16512 Result Count: 8
# http://nextprot.org/rdf/entry/NX_P29376 Result Count: 0
# http://nextprot.org/rdf/entry/NX_O14730 Result Count: 8
# http://nextprot.org/rdf/entry/NX_Q13523 Result Count: 2
# http://nextprot.org/rdf/entry/NX_Q16584 Result Count: 7
# http://nextprot.org/rdf/entry/NX_P27037 Result Count: 3
# http://nextprot.org/rdf/entry/NX_Q16832 Result Count: 8
# http://nextprot.org/rdf/entry/NX_P19525 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q9P1W9 Result Count: 8
# http://nextprot.org/rdf/entry/NX_O75460 Result Count: 4
# http://nextprot.org/rdf/entry/NX_Q05513 Result Count: 2
# http://nextprot.org/rdf/entry/NX_P57058 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P28223 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P11362 Result Count: 13
# http://nextprot.org/rdf/entry/NX_Q8IYT8 Result Count: 1
# http://nextprot.org/rdf/entry/NX_O94804 Result Count: 6
# http://nextprot.org/rdf/entry/NX_Q9Y4K4 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q7L7X3 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q9BYT3 Result Count: 2
# http://nextprot.org/rdf/entry/NX_Q8NFD2 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P68370 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q16539 Result Count: 5
# http://nextprot.org/rdf/entry/NX_Q9NQU5 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q15418 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q5VT25 Result Count: 1
# http://nextprot.org/rdf/entry/NX_O75909 Result Count: 4
# http://nextprot.org/rdf/entry/NX_O00311 Result Count: 2
# http://nextprot.org/rdf/entry/NX_P61075 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P11802 Result Count: 27
# http://nextprot.org/rdf/entry/NX_O00418 Result Count: 1
# http://nextprot.org/rdf/entry/NX_Q8NG66 Result Count: 1
# http://nextprot.org/rdf/entry/NX_O00506 Result Count: 17
# http://nextprot.org/rdf/entry/NX_P46098 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q9BVS4 Result Count: 2
# http://nextprot.org/rdf/entry/NX_O00750 Result Count: 4
# http://nextprot.org/rdf/entry/NX_Q3U3Q1 Result Count: 0
# http://nextprot.org/rdf/entry/NX_P22455 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q13873 Result Count: 2
# http://nextprot.org/rdf/entry/NX_P31751 Result Count: 11
# http://nextprot.org/rdf/entry/NX_P50406 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q05397 Result Count: 16
# http://nextprot.org/rdf/entry/NX_Q15759 Result Count: 4
# http://nextprot.org/rdf/entry/NX_P49760 Result Count: 0
# http://nextprot.org/rdf/entry/NX_Q9HBH9 Result Count: 31

# %%
tissue_results[:5]
# Out:
# [[('http://nextprot.org/rdf/entry/NX_P15735',
#    'http://nextprot.org/rdf/terminology/TS-1030',
#    'Testis')],
#  [],
#  [],
#  [],
#  [('http://nextprot.org/rdf/entry/NX_Q06418',
#    'http://nextprot.org/rdf/terminology/TS-0091',
#    'Cerebral cortex'),
#   ('http://nextprot.org/rdf/entry/NX_Q06418',
#    'http://nextprot.org/rdf/terminology/TS-0730',
#    'Ovary')]]

# %%
final_tissue_df = pd.DataFrame(list(itertools.chain.from_iterable(tissue_results)), columns=["proteinID", "tissue_id", "tissue_name"])

# %%
display(final_tissue_df)
# Out:
#                                     proteinID  \
# 0     http://nextprot.org/rdf/entry/NX_P15735
# 1     http://nextprot.org/rdf/entry/NX_Q06418
# 2     http://nextprot.org/rdf/entry/NX_Q06418
# 3     http://nextprot.org/rdf/entry/NX_P35916
# 4     http://nextprot.org/rdf/entry/NX_P00533
# ...                                       ...
# 1585  http://nextprot.org/rdf/entry/NX_Q9HBH9
# 1586  http://nextprot.org/rdf/entry/NX_Q9HBH9
# 1587  http://nextprot.org/rdf/entry/NX_Q9HBH9
# 1588  http://nextprot.org/rdf/entry/NX_Q9HBH9
# 1589  http://nextprot.org/rdf/entry/NX_Q9HBH9
#
#                                         tissue_id      tissue_name
# 0     http://nextprot.org/rdf/terminology/TS-1030           Testis
# 1     http://nextprot.org/rdf/terminology/TS-0091  Cerebral cortex
# 2     http://nextprot.org/rdf/terminology/TS-0730            Ovary
# 3     http://nextprot.org/rdf/terminology/TS-1262     Renal tubule
# 4     http://nextprot.org/rdf/terminology/TS-1070      Trophoblast
# ...                                           ...              ...
# 1585  http://nextprot.org/rdf/terminology/TS-1053           Tonsil
# 1586  http://nextprot.org/rdf/terminology/TS-0013   Adipose tissue
# 1587  http://nextprot.org/rdf/terminology/TS-1262     Renal tubule
# 1588  http://nextprot.org/rdf/terminology/TS-0568             Lung
# 1589  http://nextprot.org/rdf/terminology/TS-0933  Skeletal muscle
#
# [1590 rows x 3 columns]
